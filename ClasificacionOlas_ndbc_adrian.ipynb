# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
from hdpgpc.get_data import compute_estimators_LDS
import math
from scipy.fft import fft
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import importlib
import pickle
import hdpgpc.GPI_HDP as hdpgp
import re
from datetime import datetime, timedelta
import time

# %%
from hdpgpc.util_plots import print_results
import hdpgpc.util_plots as up
importlib.reload(up)
# Out:
# <module 'hdpgpc.util_plots' from 'C:\\Users\\marco\\OneDrive - Universidade de Santiago de Compostela (1)\\CITIUS\\HDP-GPC\\hdpgpc\\hdpgpc\\util_plots.py'>

# %% [markdown]
# ---

# %% [markdown]
# ### Datos NDBC

# %%
data = np.load('../data/Australia/OBDEP01.npy')
freq = np.load('../data/Australia/freq.npy')

# %%
data.shape
num_samples, num_obs_per_sample, num_outputs = data.shape

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Gráfica 1
axs[0, 0].plot(freq, data[0, :, 0])

# Gráfica 2
axs[0, 1].plot(freq, data[127, :, 0])

# Gráfica 3
axs[1, 0].plot(freq, data[35, :, 0])

# Gráfica 4
axs[1, 1].plot(freq, data[359, :, 0])

# Ajustar el layout para evitar superposición
plt.tight_layout()
plt.show()

# %%
#Here we are going to compute the Heighs and try to filter following Hamiltons rule.
interv = np.repeat(freq[1]-freq[0], num_obs_per_sample)[:, np.newaxis]
hs = 4 * np.sqrt(data[:,:,0] @ interv)
print("Shape of hs: "+str(hs.shape))
plt.plot(hs)
chosen_indexes = np.where((hs > 0.5) & (hs < 3.0))[0]
#chosen_indexes = np.arange(0, num_samples)
print("How much spectra falls in the range 0.5-3.0 Hs: " + str(chosen_indexes.shape[0]))
plt.show()
plt.plot(freq, data[:,:,0][chosen_indexes].T)
plt.show()
lognorm_data = np.log(data + 1e-6) - np.mean(np.log(data+ 1e-6), axis=1)[:,np.newaxis,:]
plt.plot(freq, lognorm_data[:,:,0][chosen_indexes].T)
plt.show()
# Out:
# Shape of hs: (1559, 1)
# How much spectra falls in the range 0.5-3.0 Hs: 1520

# %%
#Select indexes
data = data[chosen_indexes]
print("Shape of the data: ")
print(data.shape)

num_samples, num_obs_per_sample, num_outputs = data.shape
# Out:
# Shape of the data:
# (1520, 88, 1)

# %%
std, std_dif, bound_sigma, bound_gamma = compute_estimators_LDS(data, n_f=num_samples-1)
#Seem like these estimators are so big for this data, let's reduce them
std = std * 0.15
std_dif = std_dif * 0.05
bound_sigma = (std * 1e-7, std * 1e-1)
bound_gamma = (std_dif * 1e-9, std_dif * 1e-1)

print("Final sigma:", std)
print("Final gamma:", std_dif)
print("Final sigma bound:", bound_sigma)
print("Final gamma bound:", bound_gamma)
# Out:
# Sigma estimated: 0.09624330176339577
# Gamma estimated: 0.09624330176339577
# Final sigma: 0.014436495264509365
# Final gamma: 0.0048121650881697885
# Final sigma bound: (1.4436495264509363e-09, 0.0014436495264509366)
# Final gamma bound: (4.812165088169789e-12, 0.00048121650881697886)

# %%
M = 2
sigma = [std * 1.0] * M
gamma = [std_dif * 1.0] * M
outputscale_ = 1.0
ini_lengthscale = 1e-2
bound_lengthscale = (1e-7, 5e-1)
samples = [0, num_obs_per_sample]
l, L = samples[0], samples[1]
# x_basis has to have the same dimension structure as data[0], in this case (171,1) but it could be (n_inducing_points, 1).
x_basis = np.atleast_2d(freq[0:100]).T
x_train = np.atleast_2d(freq[0:100]).T
print(x_train.shape)
#If x_basis is wanted to be smaller than the observations length, then the inducing points approach can be applied setting this parameter to True.
inducing_points = False
#Choose if warp is going to be applied. (In the most recent version is optimized to work with online inference, but it can be used in offline as an additional step at the end of the clustering).
warp = False
#Warp priors
noise_warp = std * 0.1
bound_noise_warp = (noise_warp * 0.1, noise_warp * 0.2)
#Warp time indexes
x_basis_warp = np.atleast_2d(np.arange(freq[0], freq[-1], freq.shape[0]/2.0, dtype=np.float64)).T
# Out:
# (88, 1)

# %%
sw_gp_online = hdpgp.GPI_HDP(x_basis=x_basis, x_basis_warp=x_basis_warp, n_outputs=1,
                          ini_lengthscale=ini_lengthscale, bound_lengthscale=bound_lengthscale,
                          ini_gamma=gamma, ini_sigma=sigma, ini_outputscale=outputscale_, noise_warp=noise_warp,
                          bound_sigma=bound_sigma, bound_gamma=bound_gamma, bound_noise_warp=bound_noise_warp,
                          verbose=False, max_models=100, inducing_points=inducing_points, estimation_limit=None, annealing=False, free_deg_MNIV=5)

#Generate artificial labels to plot using util_plots.
from hdpgpc.util_plots import print_results, plot_models_plotly
num_samples = data.shape[0]
labels = np.array(['N'] * num_samples)
#mean_data = np.mean(data, axis=1)[:, np.newaxis]
#data_ = data - mean_data
for t in range(400):
    print("Sample: "+str(t))
    sw_gp_online.include_sample(x_train, data[t], with_warp=warp)
main_model = print_results(sw_gp_online, labels, 0, error=False)
selected_gpmodels = sw_gp_online.selected_gpmodels()
plot_models_plotly(sw_gp_online, selected_gpmodels, main_model, labels, N_0=0, lead=0, step=freq[1]-freq[0], plot_latent=True, ticks=True, yscale=True)
# Out:
# Sample: 0
# Main model chosen: 1
# ---Kernel estimated---
# 0.534**2 * RBF(length_scale=0.00906) + WhiteKernel(noise_level=0.00299)
# Sample: 1
# Main model chosen: 1
# Sample: 2
# Main model chosen: 1
# Sample: 3
# Main model chosen: 1
# Sample: 4
# Birth of new model:  2
# Main model chosen: 2
# ---Kernel estimated---
# 0.498**2 * RBF(length_scale=0.00894) + WhiteKernel(noise_level=0.00301)
# Sample: 5
# Main model chosen: 2
# Sample: 6
# Main model chosen: 2
# Sample: 7
# Main model chosen: 2
# Sample: 8
# Main model chosen: 2
# Sample: 9
# Main model chosen: 2
# Sample: 10
# Main model chosen: 2
# Sample: 11
# Birth of new model:  3
# Main model chosen: 3
# ---Kernel estimated---
# 0.276**2 * RBF(length_scale=0.0104) + WhiteKernel(noise_level=3.44e-07)
# Sample: 12
# Main model chosen: 3
# Sample: 13
# Main model chosen: 3
# Sample: 14
# Main model chosen: 3
# Sample: 15
# Main model chosen: 3
# Sample: 16
# Main model chosen: 3
# Sample: 17
# Main model chosen: 3
# Sample: 18
# Main model chosen: 3
# Sample: 19
# Main model chosen: 3
# Sample: 20
# Main model chosen: 3
# Sample: 21
# Main model chosen: 3
# Sample: 22
# Main model chosen: 3
# Sample: 23
# Main model chosen: 3
# Sample: 24
# Main model chosen: 3
# Sample: 25
# Main model chosen: 3
# Sample: 26
# Main model chosen: 3
# Sample: 27
# Main model chosen: 3
# Sample: 28
# Main model chosen: 3
# Sample: 29
# Main model chosen: 3
# Sample: 30
# Main model chosen: 3
# Sample: 31
# Main model chosen: 3
# Sample: 32
# Main model chosen: 3
# Sample: 33
# Main model chosen: 3
# Sample: 34
# Main model chosen: 3
# Sample: 35
# Main model chosen: 3
# Sample: 36
# Main model chosen: 3
# Sample: 37
# Main model chosen: 3
# Sample: 38
# Birth of new model:  4
# Main model chosen: 4
# ---Kernel estimated---
# 0.143**2 * RBF(length_scale=0.027) + WhiteKernel(noise_level=0.00129)
# Sample: 39
# Main model chosen: 4
# Sample: 40
# Main model chosen: 4
# Sample: 41
# Main model chosen: 4
# Sample: 42
# Main model chosen: 4
# Sample: 43
# Birth of new model:  5
# Main model chosen: 5
# ---Kernel estimated---
# 1.01**2 * RBF(length_scale=0.0103) + WhiteKernel(noise_level=0.00304)
# Sample: 44
# Birth of new model:  6
# Main model chosen: 6
# ---Kernel estimated---
# 1.92**2 * RBF(length_scale=0.00854) + WhiteKernel(noise_level=0.00305)
# Sample: 45
# Main model chosen: 6
# Sample: 46
# Birth of new model:  7
# Main model chosen: 7
# ---Kernel estimated---
# 1.79**2 * RBF(length_scale=0.00991) + WhiteKernel(noise_level=0.00304)
# Sample: 47
# Birth of new model:  8
# Main model chosen: 8
# ---Kernel estimated---
# 0.676**2 * RBF(length_scale=0.0113) + WhiteKernel(noise_level=0.003)
# Sample: 48
# Main model chosen: 2
# Sample: 49
# Main model chosen: 2
# Sample: 50
# Main model chosen: 8
# Sample: 51
# Main model chosen: 8
# Sample: 52
# Main model chosen: 8
# Sample: 53
# Birth of new model:  9
# Main model chosen: 9
# ---Kernel estimated---
# 1.27**2 * RBF(length_scale=0.0113) + WhiteKernel(noise_level=0.00302)
# Sample: 54
# Main model chosen: 9
# Sample: 55
# Main model chosen: 9
# Sample: 56
# Birth of new model:  10
# Main model chosen: 10
# ---Kernel estimated---
# 1.43**2 * RBF(length_scale=0.00994) + WhiteKernel(noise_level=0.00303)
# Sample: 57
# Birth of new model:  11
# Main model chosen: 11
# ---Kernel estimated---
# 0.864**2 * RBF(length_scale=0.00996) + WhiteKernel(noise_level=0.00298)
# Sample: 58
# Main model chosen: 10
# Sample: 59
# Main model chosen: 11
# Sample: 60
# Main model chosen: 11
# Sample: 61
# Main model chosen: 11
# Sample: 62
# Main model chosen: 11
# Sample: 63
# Main model chosen: 11
# Sample: 64
# Main model chosen: 11
# Sample: 65
# Main model chosen: 11
# Sample: 66
# Main model chosen: 11
# Sample: 67
# Main model chosen: 11
# Sample: 68
# Main model chosen: 11
# Sample: 69
# Main model chosen: 11
# Sample: 70
# Main model chosen: 11
# Sample: 71
# Main model chosen: 11
# Sample: 72
# Main model chosen: 11
# Sample: 73
# Main model chosen: 11
# Sample: 74
# Main model chosen: 11
# Sample: 75
# Main model chosen: 11
# Sample: 76
# Main model chosen: 11
# Sample: 77
# Main model chosen: 11
# Sample: 78
# Main model chosen: 11
# Sample: 79
# Main model chosen: 11
# Sample: 80
# Main model chosen: 4
# Sample: 81
# Main model chosen: 4
# Sample: 82
# Main model chosen: 4
# Sample: 83
# Main model chosen: 4
# Sample: 84
# Main model chosen: 4
# Sample: 85
# Main model chosen: 4
# Sample: 86
# Main model chosen: 4
# Sample: 87
# Main model chosen: 4
# Sample: 88
# Main model chosen: 4
# Sample: 89
# Main model chosen: 4
# Sample: 90
# Main model chosen: 4
# Sample: 91
# Main model chosen: 4
# Sample: 92
# Main model chosen: 4
# Sample: 93
# Main model chosen: 4
# Sample: 94
# Main model chosen: 4
# Sample: 95
# Main model chosen: 4
# Sample: 96
# Main model chosen: 4
# Sample: 97
# Main model chosen: 4
# Sample: 98
# Main model chosen: 4
# Sample: 99
# Main model chosen: 4
# Sample: 100
# Main model chosen: 4
# Sample: 101
# Main model chosen: 4
# Sample: 102
# Main model chosen: 4
# Sample: 103
# Main model chosen: 4
# Sample: 104
# Main model chosen: 4
# Sample: 105
# Main model chosen: 4
# Sample: 106
# Main model chosen: 4
# Sample: 107
# Main model chosen: 4
# Sample: 108
# Main model chosen: 4
# Sample: 109
# Main model chosen: 4
# Sample: 110
# Main model chosen: 4
# Sample: 111
# Main model chosen: 4
# Sample: 112
# Main model chosen: 4
# Sample: 113
# Main model chosen: 4
# Sample: 114
# Main model chosen: 4
# Sample: 115
# Main model chosen: 4
# Sample: 116
# Main model chosen: 4
# Sample: 117
# Main model chosen: 4
# Sample: 118
# Main model chosen: 2
# Sample: 119
# Main model chosen: 2
# Sample: 120
# Main model chosen: 2
# Sample: 121
# Main model chosen: 8
# Sample: 122
# Main model chosen: 8
# Sample: 123
# Main model chosen: 8
# Sample: 124
# Main model chosen: 1
# Sample: 125
# Main model chosen: 1
# Sample: 126
# Main model chosen: 5
# Sample: 127
# Main model chosen: 5
# Sample: 128
# Main model chosen: 5
# Sample: 129
# Main model chosen: 5
# Sample: 130
# Main model chosen: 5
# Sample: 131
# Main model chosen: 1
# Sample: 132
# Main model chosen: 1
# Sample: 133
# Main model chosen: 1
# Sample: 134
# Main model chosen: 1
# Sample: 135
# Main model chosen: 1
# Sample: 136
# Main model chosen: 1
# Sample: 137
# Main model chosen: 1
# Sample: 138
# Main model chosen: 1
# Sample: 139
# Main model chosen: 8
# Sample: 140
# Main model chosen: 2
# Sample: 141
# Main model chosen: 8
# Sample: 142
# Main model chosen: 8
# Sample: 143
# Main model chosen: 8
# Sample: 144
# Main model chosen: 8
# Sample: 145
# Main model chosen: 8
# Sample: 146
# Main model chosen: 8
# Sample: 147
# Birth of new model:  12
# Main model chosen: 12
# ---Kernel estimated---
# 0.352**2 * RBF(length_scale=0.00678) + WhiteKernel(noise_level=0.0031)
# Sample: 148
# Main model chosen: 12
# Sample: 149
# Main model chosen: 12
# Sample: 150
# Main model chosen: 12
# Sample: 151
# Main model chosen: 12
# Sample: 152
# Main model chosen: 12
# Sample: 153
# Main model chosen: 11
# Sample: 154
# Main model chosen: 11
# Sample: 155
# Main model chosen: 11
# Sample: 156
# Main model chosen: 11
# Sample: 157
# Main model chosen: 11
# Sample: 158
# Main model chosen: 11
# Sample: 159
# Main model chosen: 11
# Sample: 160
# Main model chosen: 11
# Sample: 161
# Main model chosen: 11
# Sample: 162
# Main model chosen: 11
# Sample: 163
# Birth of new model:  13
# Main model chosen: 13
# ---Kernel estimated---
# 0.0813**2 * RBF(length_scale=0.0246) + WhiteKernel(noise_level=0.00171)
# Sample: 164
# Main model chosen: 13
# Sample: 165
# Main model chosen: 13
# Sample: 166
# Main model chosen: 13
# Sample: 167
# Main model chosen: 13
# Sample: 168
# Main model chosen: 13
# Sample: 169
# Main model chosen: 13
# Sample: 170
# Main model chosen: 12
# Sample: 171
# Main model chosen: 12
# Sample: 172
# Main model chosen: 12
# Sample: 173
# Main model chosen: 12
# Sample: 174
# Main model chosen: 12
# Sample: 175
# Main model chosen: 12
# Sample: 176
# Main model chosen: 12
# Sample: 177
# Main model chosen: 12
# Sample: 178
# Main model chosen: 12
# Sample: 179
# Main model chosen: 12
# Sample: 180
# Main model chosen: 12
# Sample: 181
# Main model chosen: 12
# Sample: 182
# Main model chosen: 12
# Sample: 183
# Main model chosen: 12
# Sample: 184
# Main model chosen: 12
# Sample: 185
# Main model chosen: 12
# Sample: 186
# Main model chosen: 12
# Sample: 187
# Main model chosen: 12
# Sample: 188
# Main model chosen: 12
# Sample: 189
# Main model chosen: 12
# Sample: 190
# Main model chosen: 12
# Sample: 191
# Main model chosen: 12
# Sample: 192
# Main model chosen: 5
# Sample: 193
# Main model chosen: 5
# Sample: 194
# Main model chosen: 5
# Sample: 195
# Main model chosen: 5
# Sample: 196
# Main model chosen: 5
# Sample: 197
# Main model chosen: 5
# Sample: 198
# Main model chosen: 2
# Sample: 199
# Main model chosen: 2
# Sample: 200
# Main model chosen: 8
# Sample: 201
# Main model chosen: 8
# Sample: 202
# Main model chosen: 1
# Sample: 203
# Main model chosen: 1
# Sample: 204
# Main model chosen: 1
# Sample: 205
# Main model chosen: 1
# Sample: 206
# Main model chosen: 1
# Sample: 207
# Main model chosen: 5
# Sample: 208
# Main model chosen: 5
# Sample: 209
# Main model chosen: 1
# Sample: 210
# Main model chosen: 5
# Sample: 211
# Main model chosen: 5
# Sample: 212
# Main model chosen: 5
# Sample: 213
# Main model chosen: 5
# Sample: 214
# Main model chosen: 5
# Sample: 215
# Main model chosen: 5
# Sample: 216
# Main model chosen: 5
# Sample: 217
# Main model chosen: 5
# Sample: 218
# Main model chosen: 5
# Sample: 219
# Main model chosen: 5
# Sample: 220
# Main model chosen: 5
# Sample: 221
# Main model chosen: 5
# Sample: 222
# Main model chosen: 5
# Sample: 223
# Main model chosen: 5
# Sample: 224
# Main model chosen: 5
# Sample: 225
# Main model chosen: 5
# Sample: 226
# Main model chosen: 5
# Sample: 227
# Main model chosen: 5
# Sample: 228
# Main model chosen: 11
# Sample: 229
# Main model chosen: 11
# Sample: 230
# Main model chosen: 11
# Sample: 231
# Main model chosen: 11
# Sample: 232
# Main model chosen: 11
# Sample: 233
# Main model chosen: 11
# Sample: 234
# Birth of new model:  14
# Main model chosen: 14
# ---Kernel estimated---
# 0.0757**2 * RBF(length_scale=0.0117) + WhiteKernel(noise_level=0.00235)
# Sample: 235
# Main model chosen: 14
# Sample: 236
# Main model chosen: 14
# Sample: 237
# Main model chosen: 11
# Sample: 238
# Main model chosen: 11
# Sample: 239
# Main model chosen: 11
# Sample: 240
# Main model chosen: 11
# Sample: 241
# Main model chosen: 14
# Sample: 242
# Main model chosen: 14
# Sample: 243
# Main model chosen: 4
# Sample: 244
# Main model chosen: 5
# Sample: 245
# Main model chosen: 4
# Sample: 246
# Main model chosen: 4
# Sample: 247
# Main model chosen: 4
# Sample: 248
# Main model chosen: 5
# Sample: 249
# Main model chosen: 4
# Sample: 250
# Main model chosen: 4
# Sample: 251
# Main model chosen: 5
# Sample: 252
# Main model chosen: 5
# Sample: 253
# Main model chosen: 5
# Sample: 254
# Main model chosen: 5
# Sample: 255
# Main model chosen: 5
# Sample: 256
# Main model chosen: 5
# Sample: 257
# Main model chosen: 5
# Sample: 258
# Main model chosen: 8
# Sample: 259
# Main model chosen: 5
# Sample: 260
# Main model chosen: 8
# Sample: 261
# Main model chosen: 8
# Sample: 262
# Main model chosen: 8
# Sample: 263
# Main model chosen: 8
# Sample: 264
# Main model chosen: 8
# Sample: 265
# Main model chosen: 8
# Sample: 266
# Main model chosen: 8
# Sample: 267
# Main model chosen: 8
# Sample: 268
# Main model chosen: 8
# Sample: 269
# Main model chosen: 8
# Sample: 270
# Main model chosen: 8
# Sample: 271
# Main model chosen: 8
# Sample: 272
# Main model chosen: 8
# Sample: 273
# Main model chosen: 8
# Sample: 274
# Main model chosen: 8
# Sample: 275
# Main model chosen: 8
# Sample: 276
# Main model chosen: 8
# Sample: 277
# Main model chosen: 8
# Sample: 278
# Main model chosen: 8
# Sample: 279
# Main model chosen: 8
# Sample: 280
# Main model chosen: 8
# Sample: 281
# Main model chosen: 8
# Sample: 282
# Main model chosen: 8
# Sample: 283
# Main model chosen: 8
# Sample: 284
# Main model chosen: 8
# Sample: 285
# Main model chosen: 8
# Sample: 286
# Main model chosen: 8
# Sample: 287
# Main model chosen: 8
# Sample: 288
# Main model chosen: 8
# Sample: 289
# Main model chosen: 8
# Sample: 290
# Main model chosen: 8
# Sample: 291
# Main model chosen: 8
# Sample: 292
# Main model chosen: 8
# Sample: 293
# Main model chosen: 8
# Sample: 294
# Main model chosen: 8
# Sample: 295
# Birth of new model:  15
# Main model chosen: 15
# ---Kernel estimated---
# 0.372**2 * RBF(length_scale=0.0153) + WhiteKernel(noise_level=0.00324)
# Sample: 296
# Main model chosen: 15
# Sample: 297
# Main model chosen: 15
# Sample: 298
# Main model chosen: 15
# Sample: 299
# Main model chosen: 15
# Sample: 300
# Main model chosen: 15
# Sample: 301
# Main model chosen: 15
# Sample: 302
# Main model chosen: 15
# Sample: 303
# Main model chosen: 15
# Sample: 304
# Main model chosen: 15
# Sample: 305
# Main model chosen: 15
# Sample: 306
# Main model chosen: 15
# Sample: 307
# Main model chosen: 15
# Sample: 308
# Main model chosen: 15
# Sample: 309
# Main model chosen: 15
# Sample: 310
# Main model chosen: 1
# Sample: 311
# Main model chosen: 1
# Sample: 312
# Birth of new model:  16
# Main model chosen: 16
# ---Kernel estimated---
# 1.59**2 * RBF(length_scale=0.00891) + WhiteKernel(noise_level=0.00303)
# Sample: 313
# Main model chosen: 9
# Sample: 314
# Main model chosen: 9
# Sample: 315
# Main model chosen: 1
# Sample: 316
# Main model chosen: 6
# Sample: 317
# Main model chosen: 6
# Sample: 318
# Main model chosen: 1
# Sample: 319
# Main model chosen: 1
# Sample: 320
# Main model chosen: 1
# Sample: 321
# Main model chosen: 2
# Sample: 322
# Main model chosen: 2
# Sample: 323
# Main model chosen: 12
# Sample: 324
# Main model chosen: 2
# Sample: 325
# Main model chosen: 2
# Sample: 326
# Main model chosen: 12
# Sample: 327
# Main model chosen: 2
# Sample: 328
# Main model chosen: 14
# Sample: 329
# Main model chosen: 14
# Sample: 330
# Main model chosen: 13
# Sample: 331
# Main model chosen: 13
# Sample: 332
# Main model chosen: 13
# Sample: 333
# Main model chosen: 13
# Sample: 334
# Main model chosen: 13
# Sample: 335
# Main model chosen: 13
# Sample: 336
# Main model chosen: 13
# Sample: 337
# Main model chosen: 13
# Sample: 338
# Main model chosen: 13
# Sample: 339
# Main model chosen: 13
# Sample: 340
# Main model chosen: 13
# Sample: 341
# Main model chosen: 13
# Sample: 342
# Main model chosen: 14
# Sample: 343
# Main model chosen: 14
# Sample: 344
# Main model chosen: 14
# Sample: 345
# Main model chosen: 14
# Sample: 346
# Main model chosen: 14
# Sample: 347
# Main model chosen: 14
# Sample: 348
# Main model chosen: 14
# Sample: 349
# Main model chosen: 14
# Sample: 350
# Main model chosen: 2
# Sample: 351
# Main model chosen: 2
# Sample: 352
# Main model chosen: 2
# Sample: 353
# Main model chosen: 2
# Sample: 354
# Main model chosen: 2
# Sample: 355
# Main model chosen: 2
# Sample: 356
# Main model chosen: 2
# Sample: 357
# Main model chosen: 2
# Sample: 358
# Main model chosen: 2
# Sample: 359
# Main model chosen: 2
# Sample: 360
# Main model chosen: 2
# Sample: 361
# Main model chosen: 2
# Sample: 362
# Main model chosen: 2
# Sample: 363
# Main model chosen: 2
# Sample: 364
# Main model chosen: 2
# Sample: 365
# Main model chosen: 4
# Sample: 366
# Main model chosen: 4
# Sample: 367
# Main model chosen: 14
# Sample: 368
# Main model chosen: 12
# Sample: 369
# Main model chosen: 1
# Sample: 370
# Main model chosen: 6
# Sample: 371
# Main model chosen: 6
# Sample: 372
# Main model chosen: 6
# Sample: 373
# Main model chosen: 6
# Sample: 374
# Main model chosen: 10
# Sample: 375
# Main model chosen: 10
# Sample: 376
# Main model chosen: 10
# Sample: 377
# Main model chosen: 10
# Sample: 378
# Main model chosen: 10
# Sample: 379
# Main model chosen: 10
# Sample: 380
# Main model chosen: 10
# Sample: 381
# Main model chosen: 10
# Sample: 382
# Main model chosen: 10
# Sample: 383
# Main model chosen: 10
# Sample: 384
# Main model chosen: 10
# Sample: 385
# Main model chosen: 10
# Sample: 386
# Main model chosen: 10
# Sample: 387
# Main model chosen: 10
# Sample: 388
# Main model chosen: 10
# Sample: 389
# Main model chosen: 10
# Sample: 390
# Main model chosen: 10
# Sample: 391
# Main model chosen: 10
# Sample: 392
# Main model chosen: 10
# Sample: 393
# Main model chosen: 10
# Sample: 394
# Main model chosen: 10
# Sample: 395
# Main model chosen: 10
# Sample: 396
# Main model chosen: 10
# Sample: 397
# Main model chosen: 10
# Sample: 398
# Main model chosen: 10
# Sample: 399
# Main model chosen: 10
# Model 1 : MainModel: N : [N-27]
# Model 2 : MainModel: N : [N-35]
# Model 3 : MainModel: N : [N-27]
# Model 4 : MainModel: N : [N-51]
# Model 5 : MainModel: N : [N-42]
# Model 6 : MainModel: N : [N-8]
# Model 7 : MainModel: N : [N-1]
# Model 8 : MainModel: N : [N-52]
# Model 9 : MainModel: N : [N-5]
# Model 10 : MainModel: N : [N-28]
# Model 11 : MainModel: N : [N-42]
# Model 12 : MainModel: N : [N-31]
# Model 13 : MainModel: N : [N-19]
# Model 14 : MainModel: N : [N-16]
# Model 15 : MainModel: N : [N-15]
# Model 16 : MainModel: N : [N-1]
# Model 17  : []
# Classification error:  0.0 / 400 -- 0.0

# %%
sw_gp = hdpgp.GPI_HDP(x_basis=x_basis, x_basis_warp=x_basis_warp, n_outputs=1,
                          ini_lengthscale=ini_lengthscale, bound_lengthscale=bound_lengthscale,
                          ini_gamma=gamma, ini_sigma=sigma, ini_outputscale=outputscale_, noise_warp=noise_warp,
                          bound_sigma=bound_sigma, bound_gamma=bound_gamma, bound_noise_warp=bound_noise_warp,
                          verbose=False, max_models=100, inducing_points=inducing_points, reestimate_initial_params=False,
                          n_explore_steps=10, free_deg_MNIV=20)

#logdata = np.log(data + 1e-6)
x_trains = np.array([x_train] * num_samples)
sw_gp.include_batch(x_trains, data[:num_samples,:,[0]])
# Out:
# Group responsability estimated: [1520    0]
# ---Kernel estimated---
# 0.19**2 * RBF(length_scale=0.0157) + WhiteKernel(noise_level=0.00065)
#
# -----------Lead 1-----------
# Step 1/10- Trying to divide: 0 with beat 948
# ---Kernel estimated---
# 1.66**2 * RBF(length_scale=0.00952) + WhiteKernel(noise_level=0.00134)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
# Current resp: tensor([1513.,    7.])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
# Current resp: tensor([1513.,    7.])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1513.,    7.])
# Q_bas: tensor(-34429.3361), Q_lat: tensor(-55369.3370), Elbo_bas: tensor([-61298.3112])
# Q_bas_post: tensor(-34211.7087), Q_lat: tensor(-54010.0220), Elbo_post: tensor([-57063.2587])
# Chosen to divide: 0 with beat 948
# First resp: tensor([1513.,    7.])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
# Current resp: tensor([1513.,    7.])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-34211.7087)
# ELBO: tensor([-91317.4608])
#
# -------Lower Bound Iteration 1-------
# Group responsability estimated: [1513    7]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Sum resp_temp: tensor([1509.0117,   11.0074,    0.0000])
# Q_bas: tensor(-34211.7087), Q_lat: tensor(-54010.0220), Elbo_bas: tensor([-57017.8508])
# Q_bas_post: tensor(-34145.4605), Q_lat: tensor(-53609.8977), Elbo_post: tensor([-56629.4696])
# Reallocating beats into existing groups.
# First resp: tensor([1509.0117,   11.0074,    0.0000])
# Mean_sq: tensor(-34145.4605)
# ELBO: tensor([-90774.4034])
#
# -------Lower Bound Iteration 2-------
# Group responsability estimated: [1509   11    0]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Sum resp_temp: tensor([1509.0110,   11.0219,    0.0000])
# Q_bas: tensor(-34145.4605), Q_lat: tensor(-53609.8977), Elbo_bas: tensor([-56629.4258])
# Q_bas_post: tensor(-34145.4605), Q_lat: tensor(-53609.8977), Elbo_post: tensor([-56628.5005])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 0 with beat 601
# ---Kernel estimated---
# 1.17**2 * RBF(length_scale=0.00904) + WhiteKernel(noise_level=0.00134)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Current resp: tensor([1483.0000,   27.0180,   10.0331])
# ELBO_reduction: 208.37965492744115
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Current resp: tensor([1483.0000,   27.0180,   10.0331])
# ELBO_reduction: 95.99689275946002
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Current resp: tensor([1483.0000,   27.0180,   10.0331])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1483.0000,   27.0180,   10.0331])
# Q_bas: tensor(-34145.4605), Q_lat: tensor(-53609.8977), Elbo_bas: tensor([-56629.4258])
# Q_bas_post: tensor(-33705.5271), Q_lat: tensor(-50812.9862), Elbo_post: tensor([-53045.9407])
# Chosen to divide: 0 with beat 601
# First resp: tensor([1483.0000,   27.0180,   10.0331])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
# Current resp: tensor([1483.0000,   27.0180,   10.0331])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-33705.5271)
# ELBO: tensor([-86755.3315])
#
# -------Lower Bound Iteration 3-------
# Group responsability estimated: [1483   27   10]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Sum resp_temp: tensor([1457.0907,   52.0127,   11.0766,    0.0000])
# Q_bas: tensor(-33705.5271), Q_lat: tensor(-50812.9862), Elbo_bas: tensor([-52885.2101])
# Q_bas_post: tensor(-34253.1287), Q_lat: tensor(-46131.0742), Elbo_post: tensor([-48213.2230])
# Reallocating beats into existing groups.
# First resp: tensor([1457.0907,   52.0127,   11.0766,    0.0000])
# Mean_sq: tensor(-34253.1287)
# ELBO: tensor([-82462.1378])
#
# -------Lower Bound Iteration 4-------
# Group responsability estimated: [1457   52   11    0]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Sum resp_temp: tensor([1457.1133,   52.0150,   11.0169,    0.0000])
# Q_bas: tensor(-34253.1287), Q_lat: tensor(-46131.0742), Elbo_bas: tensor([-48212.8313])
# Q_bas_post: tensor(-34253.1287), Q_lat: tensor(-46131.0742), Elbo_post: tensor([-48213.3222])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 1 with beat 601
# ---Kernel estimated---
# 0.968**2 * RBF(length_scale=0.0133) + WhiteKernel(noise_level=0.00132)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1443.3381,   57.5416,   11.0739,    9.0000])
# ELBO_reduction: 819.3443013043725
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1440.0116,   62.1102,   11.0716,    9.0000])
# ELBO_reduction: 390.9770504227199
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1437.0000,   63.1493,   11.0716,    9.0000])
# ELBO_reduction: 211.83250577707076
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1436.9685,   64.1493,   11.0716,    9.0000])
# ELBO_reduction: 150.8339528227225
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1436.9685,   64.1493,   11.0716,    9.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1436.9685,   64.1493,   11.0716,    9.0000])
# Q_bas: tensor(-34253.1287), Q_lat: tensor(-46131.0742), Elbo_bas: tensor([-48212.8313])
# Q_bas_post: tensor(-33611.9625), Q_lat: tensor(-44501.7930), Elbo_post: tensor([-46256.3407])
# Chosen to divide: 1 with beat 601
# First resp: tensor([1436.9685,   64.1493,   11.0716,    9.0000])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
# Current resp: tensor([1436.9685,   64.1493,   11.0716,    9.0000])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-33611.9625)
# ELBO: tensor([-79886.2562])
#
# -------Lower Bound Iteration 5-------
# Group responsability estimated: [1436   64   11    9]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Sum resp_temp: tensor([1413.9452,   64.7951,   38.1946,    6.0000,    0.0000])
# Q_bas: tensor(-33611.9625), Q_lat: tensor(-44501.7930), Elbo_bas: tensor([-46122.2976])
# Q_bas_post: tensor(-33908.1981), Q_lat: tensor(-42810.8138), Elbo_post: tensor([-44476.2061])
# Reallocating beats into existing groups.
# First resp: tensor([1413.9452,   64.7951,   38.1946,    6.0000,    0.0000])
# Mean_sq: tensor(-33908.1981)
# ELBO: tensor([-78367.5006])
#
# -------Lower Bound Iteration 6-------
# Group responsability estimated: [1413   64   38    6    0]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Sum resp_temp: tensor([1414.0339,   64.7919,   38.1944,    6.0000,    0.0000])
# Q_bas: tensor(-33908.1981), Q_lat: tensor(-42810.8138), Elbo_bas: tensor([-44475.3984])
# Q_bas_post: tensor(-33908.1981), Q_lat: tensor(-42810.8138), Elbo_post: tensor([-44469.8956])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 0 with beat 1518
# ---Kernel estimated---
# 0.305**2 * RBF(length_scale=0.314) + WhiteKernel(noise_level=0.00144)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([1061.4797,  340.5462,   77.6451,   45.0243,    6.0000])
# ELBO_reduction: 437.0386328468594
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([1033.6260,  342.8623,   95.3741,   47.8611,    6.0000])
# ELBO_reduction: 824.135944064139
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([1019.5679,  344.6725,  108.3018,   47.9750,    6.0000])
# ELBO_reduction: 346.44962056454096
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([1000.8872,  346.9771,  123.7211,   48.0870,    6.0000])
# ELBO_reduction: 456.69808821802144
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([995.8550, 346.2172, 130.0988,  48.0107,   6.0000])
# ELBO_reduction: 45.821312388332444
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([989.9425, 344.9851, 136.5446,  47.9849,   6.0000])
# ELBO_reduction: 107.40911426428647
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([989.9425, 344.9851, 136.5446,  47.9849,   6.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([989.9425, 344.9851, 136.5446,  47.9849,   6.0000])
# Q_bas: tensor(-33908.1981), Q_lat: tensor(-42810.8138), Elbo_bas: tensor([-44475.3984])
# Q_bas_post: tensor(-32083.2936), Q_lat: tensor(-31347.3119), Elbo_post: tensor([-32957.3880])
# Chosen to divide: 0 with beat 1518
# First resp: tensor([989.9425, 344.9851, 136.5446,  47.9849,   6.0000])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
# Current resp: tensor([989.9425, 344.9851, 136.5446,  47.9849,   6.0000])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-32083.2936)
# ELBO: tensor([-65036.2093])
#
# -------Lower Bound Iteration 7-------
# Group responsability estimated: [989 344 136  47   6]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Sum resp_temp: tensor([1163.7139,  247.8666,   65.5288,   43.0928,    6.0000,    0.0000])
# Q_bas: tensor(-32083.2936), Q_lat: tensor(-31347.3119), Elbo_bas: tensor([-32837.8653])
# Q_bas_post: tensor(-32141.7122), Q_lat: tensor(-32665.9935), Elbo_post: tensor([-34134.5380])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 2 with beat 970
# ---Kernel estimated---
# 0.328**2 * RBF(length_scale=0.0139) + WhiteKernel(noise_level=0.00133)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([952.2663, 372.9311,  72.7743,  84.1795,  42.1098,   6.0000])
# ELBO_reduction: 732.8142623195745
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([906.6096, 378.4430, 120.5090,  75.0647,  44.1558,   6.0000])
# ELBO_reduction: 1450.1861397701578
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([872.3925, 386.7688, 142.1186,  76.2471,  49.3662,   6.0000])
# ELBO_reduction: 950.7028934147966
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([849.6068, 392.6111, 154.1609,  79.2247,  49.1178,   6.0000])
# ELBO_reduction: 261.8427926220029
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([835.2131, 396.5216, 159.8158,  81.1713,  50.1322,   6.0000])
# ELBO_reduction: 114.69798486454238
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([823.7184, 398.2628, 164.0488,  84.1035,  50.1113,   6.0000])
# ELBO_reduction: 59.97436743688013
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([823.7184, 398.2628, 164.0488,  84.1035,  50.1113,   6.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([823.7184, 398.2628, 164.0488,  84.1035,  50.1113,   6.0000])
# Q_bas: tensor(-32083.2936), Q_lat: tensor(-31347.3119), Elbo_bas: tensor([-32837.8653])
# Q_bas_post: tensor(-30887.9115), Q_lat: tensor(-27725.9929), Elbo_post: tensor([-29163.8653])
# Chosen to divide: 2 with beat 970
# First resp: tensor([823.7184, 398.2628, 164.0488,  84.1035,  50.1113,   6.0000])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
# Current resp: tensor([823.7184, 398.2628, 164.0488,  84.1035,  50.1113,   6.0000])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-30887.9115)
# ELBO: tensor([-60056.6471])
#
# -------Lower Bound Iteration 8-------
# Group responsability estimated: [823 398 164  84  50   6]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Sum resp_temp: tensor([1007.4806,  238.9082,  234.5064,   33.0000,   10.0082,    7.0000,
#            0.0000])
# Q_bas: tensor(-30887.9115), Q_lat: tensor(-27725.9929), Elbo_bas: tensor([-29054.4757])
# Q_bas_post: tensor(-31769.8383), Q_lat: tensor(-26600.0717), Elbo_post: tensor([-27933.3693])
# Reallocating beats into existing groups.
# First resp: tensor([1007.4806,  238.9082,  234.5064,   33.0000,   10.0082,    7.0000,
#            0.0000])
# Mean_sq: tensor(-31769.8383)
# ELBO: tensor([-59659.8399])
#
# -------Lower Bound Iteration 9-------
# Group responsability estimated: [1007  238  234   33   10    7    0]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Sum resp_temp: tensor([1007.9780,  239.0196,  232.8776,   33.0000,   10.0070,    7.0000,
#            0.0000])
# Q_bas: tensor(-31769.8383), Q_lat: tensor(-26600.0717), Elbo_bas: tensor([-27931.6960])
# Q_bas_post: tensor(-31769.8383), Q_lat: tensor(-26600.0717), Elbo_post: tensor([-27920.4511])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 3 with beat 601
# ---Kernel estimated---
# 0.968**2 * RBF(length_scale=0.0133) + WhiteKernel(noise_level=0.00132)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Current resp: tensor([901.3487, 251.6823, 328.4860,  30.0000,  10.0838,   8.0000,   6.0000])
# ELBO_reduction: 2155.497500881771
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Current resp: tensor([815.7720, 407.3025, 255.2175,  30.0008,  11.9812,   8.0000,   5.0000])
# ELBO_reduction: 647.8181409721874
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Current resp: tensor([815.7720, 407.3025, 255.2175,  30.0008,  11.9812,   8.0000,   5.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([815.7720, 407.3025, 255.2175,  30.0008,  11.9812,   8.0000,   5.0000])
# Q_bas: tensor(-31769.8383), Q_lat: tensor(-26600.0717), Elbo_bas: tensor([-27931.6960])
# Q_bas_post: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_post: tensor([-26287.9571])
# Chosen to divide: 3 with beat 601
# First resp: tensor([815.7720, 407.3025, 255.2175,  30.0008,  11.9812,   8.0000,   5.0000])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
# Current resp: tensor([815.7720, 407.3025, 255.2175,  30.0008,  11.9812,   8.0000,   5.0000])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-30352.4524)
# ELBO: tensor([-56642.9263])
#
# -------Lower Bound Iteration 10-------
# Group responsability estimated: [815 407 255  30  11   8   5]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Sum resp_temp: tensor([995.9678, 253.1209, 202.7322,  43.5390,  26.0000,   5.1695,   1.0000,
#           0.0000])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-31652.0889), Q_lat: tensor(-26129.2946), Elbo_post: tensor([-27314.0179])
# Not reallocating, trying to generate new group.
# Step 1/10- Trying to divide: 6 with beat 945
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 2.1353e-11,
#         1.4482e-01, 9.2831e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 2.1353e-11,
#         1.4482e-01, 9.2831e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 2.1353e-11,
#         1.4482e-01, 9.2831e-02])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-285887.9811), Q_lat: tensor(-407.6437), Elbo_post: tensor([-1281.1221])
# Bad estimation
# Step 2/10- Trying to divide: 1 with beat 590
# ---Kernel estimated---
# 0.688**2 * RBF(length_scale=0.0138) + WhiteKernel(noise_level=0.00132)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([989.8275, 259.3958, 203.1141,  26.0000,  24.0480,  19.0025,   5.0000,
#           1.0000])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([989.8275, 259.3958, 203.1141,  26.0000,  24.0480,  19.0025,   5.0000,
#           1.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([989.8275, 259.3958, 203.1141,  26.0000,  24.0480,  19.0025,   5.0000,
#           1.0000])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-31603.7750), Q_lat: tensor(-25820.2962), Elbo_post: tensor([-26920.6013])
# Step 3/10- Trying to divide: 4 with beat 951
# ---Kernel estimated---
# 0.924**2 * RBF(length_scale=0.0142) + WhiteKernel(noise_level=0.00132)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([9.9498e+02, 2.5312e+02, 2.0237e+02, 3.2829e+01, 2.6000e+01, 1.5000e+01,
#         3.0000e+00, 3.8084e-56])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([9.9498e+02, 2.5312e+02, 2.0237e+02, 3.2829e+01, 2.6000e+01, 1.5000e+01,
#         3.0000e+00, 3.8084e-56])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([9.9498e+02, 2.5312e+02, 2.0237e+02, 3.2829e+01, 2.6000e+01, 1.5000e+01,
#         3.0000e+00, 3.8084e-56])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-31595.4969), Q_lat: tensor(-26128.2761), Elbo_post: tensor([-27212.5108])
# Bad estimation
# Step 4/10- Trying to divide: 1 with beat 1109
# ---Kernel estimated---
# 0.557**2 * RBF(length_scale=0.0107) + WhiteKernel(noise_level=0.00134)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([994.8341, 253.0170, 147.8798,  85.8652,  21.0000,  17.0000,   6.0000,
#           1.0000])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([994.8341, 253.0170, 147.8798,  85.8652,  21.0000,  17.0000,   6.0000,
#           1.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([994.8341, 253.0170, 147.8798,  85.8652,  21.0000,  17.0000,   6.0000,
#           1.0000])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-31634.3316), Q_lat: tensor(-25900.9976), Elbo_post: tensor([-26987.8634])
# Step 5/10- Trying to divide: 4 with beat 946
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 8.1830e-12,
#         1.4482e-01, 9.2831e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 8.1830e-12,
#         1.4482e-01, 9.2831e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0051e+00, 1.0002e+00, 1.0000e+00, 1.0000e+00, 1.5164e+03, 8.1830e-12,
#         1.4482e-01, 9.2831e-02])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-285887.9811), Q_lat: tensor(-409.3775), Elbo_post: tensor([-1282.0412])
# Bad estimation
# Step 6/10- Trying to divide: 0 with beat 717
# ---Kernel estimated---
# 0.131**2 * RBF(length_scale=0.0271) + WhiteKernel(noise_level=0.0014)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([936.0068, 238.2338, 199.1518,  80.1893,  43.5493,  26.0000,   5.1506,
#           1.0000])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([936.0068, 238.2338, 199.1518,  80.1893,  43.5493,  26.0000,   5.1506,
#           1.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([936.0068, 238.2338, 199.1518,  80.1893,  43.5493,  26.0000,   5.1506,
#           1.0000])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-31193.5360), Q_lat: tensor(-25123.3851), Elbo_post: tensor([-26320.2398])
# Step 7/10- Trying to divide: 0 with beat 933
# ---Kernel estimated---
# 0.337**2 * RBF(length_scale=0.015) + WhiteKernel(noise_level=0.00133)
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000])
# Q_bas: tensor(-30352.4524), Q_lat: tensor(-24925.0809), Elbo_bas: tensor([-26141.9613])
# Q_bas_post: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_post: tensor([-23402.8491])
# Chosen to divide: 0 with beat 933
# First resp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000])
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
# Bad estimation
# Current resp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000])
# ELBO_reduction: 0.0
# Mean_sq: tensor(-30987.4201)
# ELBO: tensor([-54345.4008])
#
# -------Lower Bound Iteration 11-------
# Group responsability estimated: [560 580 219 106  41  26   5   1]
#
# -----------Lead 1-----------
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Sum resp_temp: tensor([675.8722, 536.5778, 141.4293, 114.5611,  34.6315,  26.0039,   6.0000,
#           0.0000,   0.0000])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-30896.5245), Q_lat: tensor(-22537.4349), Elbo_post: tensor([-23798.3166])
# Bad estimation
# Step 1/10- Trying to divide: 4 with beat 946
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.1079e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.1079e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.1079e-12, 1.4399e-01, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-428.8700), Elbo_post: tensor([-1229.8575])
# Bad estimation
# Step 2/10- Trying to divide: 4 with beat 600
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1506e-11, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1506e-11, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1506e-11, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-429.1076), Elbo_post: tensor([-1228.5544])
# Bad estimation
# Step 3/10- Trying to divide: 7 with beat 945
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         1.6021e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         1.6021e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         1.6021e-12, 1.4399e-01, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-428.4869), Elbo_post: tensor([-1229.3634])
# Bad estimation
# Step 4/10- Trying to divide: 1 with beat 960
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.4593e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.4593e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         3.4593e-12, 1.4399e-01, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-428.3034), Elbo_post: tensor([-1229.5888])
# Bad estimation
# Step 5/10- Trying to divide: 4 with beat 601
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1369e-11, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1369e-11, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.1369e-11, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-429.2458), Elbo_post: tensor([-1228.3869])
# Bad estimation
# Step 6/10- Trying to divide: 0 with beat 717
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0023e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 7.3429e+00, 1.5100e+03,
#         6.5256e-03, 1.4399e-01, 4.7920e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0023e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 7.3429e+00, 1.5100e+03,
#         6.5256e-03, 1.4399e-01, 4.7920e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0023e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 7.3429e+00, 1.5100e+03,
#         6.5256e-03, 1.4399e-01, 4.7920e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-594461.9582), Q_lat: tensor(-569.1160), Elbo_post: tensor([-1377.0913])
# Bad estimation
# Step 7/10- Trying to divide: 7 with beat 944
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         4.4235e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         4.4235e-12, 1.4399e-01, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         4.4235e-12, 1.4399e-01, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-427.5705), Elbo_post: tensor([-1228.8599])
# Bad estimation
# Step 8/10- Trying to divide: 1 with beat 1192
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0008e+00, 1.0003e+00, 1.5161e+03, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 5.7013e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0008e+00, 1.0003e+00, 1.5161e+03, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 5.7013e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0008e+00, 1.0003e+00, 1.5161e+03, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 5.7013e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-856394.4986), Q_lat: tensor(-4407.8042), Elbo_post: tensor([-5206.0239])
# Bad estimation
# Step 9/10- Trying to divide: 0 with beat 1515
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.5171e+03, 4.0827e-01, 1.0005e+00, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 1.6126e-03])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.5171e+03, 4.0827e-01, 1.0005e+00, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 1.6126e-03])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.5171e+03, 4.0827e-01, 1.0005e+00, 1.0000e+00, 1.0000e+00, 4.7920e-02,
#         6.5256e-03, 1.4399e-01, 1.6126e-03])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-445858.1092), Q_lat: tensor(-6422.6306), Elbo_post: tensor([-7208.7084])
# Bad estimation
# Step 10/10- Trying to divide: 6 with beat 948
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.0962e-11, 5.8736e-02])
# ELBO_reduction: 0.0
#
# -----------Lead 1-----------
#
#    -----------Model 1-----------
#
#    -----------Model 2-----------
#
#    -----------Model 3-----------
#
#    -----------Model 4-----------
#
#    -----------Model 5-----------
#
#    -----------Model 6-----------
#
#    -----------Model 7-----------
#
#    -----------Model 8-----------
#
#    -----------Model 9-----------
# Bad estimation
# Current resp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.0962e-11, 5.8736e-02])
# ELBO_reduction: 0.0
# Sum resp_temp: tensor([1.0026e+00, 1.0003e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.5151e+03,
#         6.5297e-03, 2.0962e-11, 5.8736e-02])
# Q_bas: tensor(-30987.4201), Q_lat: tensor(-22163.0445), Elbo_bas: tensor([-23379.5516])
# Q_bas_post: tensor(-285657.2358), Q_lat: tensor(-429.6413), Elbo_post: tensor([-1227.7705])
# Bad estimation
# First resp: tensor([560.5201, 580.5198, 219.7850, 106.1876,  41.9309,  26.0000,   5.1506,
#           1.0000,   0.0000])
# Mean_sq: tensor(-30987.4201)
# ELBO: tensor([-54315.7082])
#
# -------Lower Bound Iteration 12-------

# %%
from matplotlib.colors import to_hex
color = {0: 'k', 1: 'b', 2: 'r', 3: 'g', 4: 'c', 5: 'purple', 6: 'darkgreen', 7: 'maroon',
         8: 'orange', 9: 'lightgreen', 10: 'magenta', 11: 'lightblue', 12: 'darkblue', 13: 'red',
         14: 'red', 15: 'goldenrod', 16: 'red'}
labels_trans = {'N': 1, 'V': 2, 'R': 3, '!': 4, 'F': 5, 'L': 6, 'A': 7, '/': 8, 'Q': 9, 'f': 10, 'E': 11,
                'J': 12, 'j': 13, 'e': 14, 'a': 15, 'S': 16}
def plot_models_plotly(sw_gp, selected_gpmodels, main_model, labels, N_0, title=None, save=None, lead=0, step=0.1, plot_latent=False, ticks=False, yscale=False):
    num_models = len(selected_gpmodels)
    num_cols = int(np.ceil(np.sqrt(num_models)))
    num_rows = int(np.ceil(num_models / num_cols))

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(25, 20), squeeze=False)
    axes = axes.flatten()

    def col_fun(lab):
        if type(labels[0]) is np.int32:
            return to_hex(color.get(lab, 'b'))
        else:
            return to_hex(color.get(labels_trans.get(lab, 0), 'b'))

    for i, m in enumerate(selected_gpmodels):
        ax = axes[i]
        gp = sw_gp.gpmodels[lead][m]

        # Plot training data
        for j_, d in enumerate(gp.y_train):
            j = gp.indexes[j_]
            x_t = gp.x_train[j_].T[0]
            d = sw_gp.y_train[j,:,[lead]]
            if isinstance(d, torch.Tensor):
                d = d.detach().cpu()
                x_t = x_t.cpu()
            ax.plot(x_t, d.T[0], alpha=max(0.07, 0.5 / (np.log(len(gp.y_train) - j_ + 1) + 1)),
                    color=col_fun(labels[j + N_0]), linewidth=1.2)

        # Mean and variance
        x_b = gp.x_basis.T[0]
        if (x_b[1] - x_b[0]) == step:
            x_ = torch.clone(x_b)
        else:
            x_ = torch.arange(min(x_b), max(x_b), step, dtype=torch.float64).cpu()

        mean_, Sig_ = gp.observe_last(torch.atleast_2d(x_).T)
        #mean_l, Sig_l = gp.step_forward_last(torch.atleast_2d(x_).T)

        noise_ob = np.sqrt(np.diag(Sig_.cpu()))
        mean = mean_.cpu().T[0]
        neg_lim = mean - 1.9 * noise_ob
        neg_lim[neg_lim < 0.0] = 0.0
        ax.plot(x_, mean, color='black', linewidth=2, label=f'Emission GP mean [{m + 1}]')
        ax.fill_between(x_, neg_lim, mean + 1.9 * noise_ob, color=col_fun(main_model[i]), alpha=0.3)

        # Latent mean
        mean_latent = gp.f_star_sm[-1].cpu().T[0]
        noise_lat = 1.9 * np.sqrt(np.diag(gp.Gamma[-1].cpu()))
        neg_lim = mean_latent - noise_lat
        neg_lim[neg_lim < 0.0] = 0.0
        # ax.plot(x_b.cpu(), mean_latent, color='grey', linewidth=1.5, label=f'Latent GP Mean [{m + 1}]')
        ax.fill_between(x_b.cpu(), neg_lim, mean_latent+noise_lat, color=col_fun(main_model[i]), alpha=0.22)

        #Experimental mean
        mean = np.mean(np.array(gp.y_train), axis=0)
        ax.plot(x_b.cpu(), mean, color='black', linewidth=2, label=f'Experimental mean [{m + 1}]', linestyle='--')

        if title is None:
            ax.set_title(f"ECG CLUSTER {m + 1} ({main_model[m]})")
        else:
            ax.set_title(title)
        #ax.grid(True)
    if yscale:
        for ax in fig.get_axes():
            ax.set_ylim(np.min(sw_gp.y_train.numpy())-0.5, np.max(sw_gp.y_train.numpy()) + 0.5)
            ax.set_xticks(np.arange(0.0,0.5,0.1))
    if not ticks:
        for ax in fig.get_axes():
        #     ax.label_outer()
        #     ax.set_yticklabels([])
            ax.set_xticklabels([])
            ax.set_xticks([])
        #     ax.set_yticks([])
    # Hide unused subplots
    for j in range(len(axes)):
        if j >= num_models:
            axes[j].axis('off')

    fig.tight_layout()
    if save:
        plt.savefig(save)
    else:
        plt.show()

# %%
labels = np.array(['N'] * num_samples)
main_model = print_results(sw_gp, labels, 0, error=False)
selected_gpmodels = sw_gp.selected_gpmodels()
plot_models_plotly(sw_gp, selected_gpmodels, main_model, labels, N_0=0, lead=0, step=freq[1]-freq[0],
                   plot_latent=False, title='WAVE CLUSTER', ticks=True, yscale=True, save="/home/adrian.perez/Documents/OceanWave/HDP-GPC/hdpgpc/ocean/clusters_ndbc.png")
# Out:
# Model 1 : MainModel: N : [N-3303]
# Model 2 : MainModel: N : [N-1588]
# Model 3 : MainModel: N : [N-1371]
# Model 4 : MainModel: N : [N-390]
# Model 5 : MainModel: N : [N-381]
# Model 6 : MainModel: N : [N-348]
# Model 7 : MainModel: N : [N-288]
# Model 8 : MainModel: N : [N-159]
# Model 9 : MainModel: N : [N-110]
# Model 10 : MainModel: N : [N-80]
# Model 11 : MainModel: N : [N-62]
# Model 12 : MainModel: N : [N-29]
# Model 13 : MainModel: N : [N-16]
# Model 14 : MainModel: N : [N-14]
# Model 15 : MainModel: N : [N-8]
# Model 16 : MainModel: N : [N-7]
# Model 17 : MainModel: N : [N-6]
# Classification error:  0.0 / 8160 -- 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

class FunctionEvolutionVisualizer:
    def __init__(self, gp, initial_step, num_steps):
        """
        Initialize the visualizer with required parameters.

        Parameters:
        - gp: GP_model.
        - initial_step: Initial time step for animation.
        - num_steps: Number of time steps to simulate.
        """
        self.gp = gp
        self.num_steps = num_steps
        self.initial_step = initial_step

        # Initialize figure and lines for animation
        self.fig, self.ax = plt.subplots(figsize=(8, 6))
        self.lines = {
            "prediction": self.ax.plot([], [], label="Predicted Mean", color="red")[0],
            "observation": self.ax.plot([], [], label="Observation", color="blue")[0],
            "correction": self.ax.plot([], [], label="Corrected Mean", color="green")[0],
        }

        # Add fill_between for variance band (initially empty)
        self.variance_band = None

        # Set plot properties
        self.ax.legend()
        self.ax.set_xlim(0.0, 0.5)
        self.ax.set_ylim(0.0, 7.0)
        self.ax.set_xlabel("Frequency (Hz)")
        self.ax.set_ylabel("Energy")
        self.ax.set_title("Function Evolution Over Time")

    def init_animation(self):
        """Initialize the animation by clearing all lines."""
        for line in self.lines.values():
            line.set_data([], [])

        # Clear the variance band if it exists
        if self.variance_band is not None:
            self.variance_band.remove()
            self.variance_band = None

        return list(self.lines.values())

    def animate(self, i):
        """
        Animation function for each frame.

        Parameters:
        - i: Current frame index.

        Steps:
        1. Show prediction.
        2. Show observation.
        3. Show correction.

        Each step is shown with a delay of half a second (500 ms).
        """
        # Determine which logical step (sub-frame) we are in
        step = i % 4  # Cycle through 0 (prediction), 1 (observation), 2 (correction)
        j = self.initial_step + i // 4  # Determine the actual time step

        if j >= len(self.gp.x_train):  # Stop if we exceed available data
            return list(self.lines.values())

        x_ = self.gp.x_train[j].T[0]

        if step == 0:  # First correction step
            if i == 0:
                # Initialize the current function for new animation
                self.current_function = self.gp.f_star[j].T[0].numpy().copy()
                self.lines["correction"].set_data(x_, self.current_function)
            # Update the title dynamically with the current time step
            self.ax.set_title(f"Function Evolution Over Time - Time Step: {j}")

            # Clear observation and correction temporarily
            self.lines["observation"].set_data([], [])
            self.lines["prediction"].set_data([], [])
            # Clear observation and prediction temporarily
            if self.variance_band is not None:
                self.variance_band.remove()
                self.variance_band = None

        elif step == 1:  # Prediction step

            predicted_f = np.linalg.matrix_power(self.gp.A[j].numpy(),20) @ self.current_function
            self.lines["prediction"].set_data(x_, predicted_f)

            variance = np.sqrt(torch.diag(self.gp.Gamma[j]).numpy()) * 1.96
            # Update variance band dynamically
            if self.variance_band is not None:
                self.variance_band.remove()  # Remove the old band
            lower_bound = predicted_f - variance
            upper_bound = predicted_f + variance
            self.variance_band = self.ax.fill_between(x_, lower_bound, upper_bound, color="red", alpha=0.2)

        elif step == 2:  # Observation step

            observed_f = self.gp.y_train[j].T[0].numpy()
            self.lines["observation"].set_data(x_, observed_f)

        elif step == 3:

            corrected_f = self.gp.f_star[j + 1].T[0].numpy().copy()
            self.lines["correction"].set_data(x_, corrected_f)

            # Update current function for the next iteration
            self.current_function = corrected_f

        return list(self.lines.values())

    def create_animation(self, output_filename="function_evolution.gif"):
        """
        Create and save the animation as a GIF.

        Parameters:
          - output_filename: Name of the output GIF file.

        Returns:
          None
          (The GIF will be saved to disk.)
        """

        ani = animation.FuncAnimation(
            self.fig,
            func=self.animate,
            init_func=self.init_animation,
            frames=self.num_steps,
            interval=400,
            blit=False,
            repeat=False,
        )

        ani.save(output_filename, writer="pillow")

# %%
gp = sw_gp.gpmodels[0][3]
initial_step = 53
num_steps = 15 * 4  # Number of time steps to simulate

# Create visualizer instance
visualizer = FunctionEvolutionVisualizer(gp, initial_step, num_steps)

# Generate animation and save as GIF
visualizer.create_animation(output_filename="/home/adrian.perez/Documents/OceanWave/HDP-GPC/hdpgpc/ocean/function_evolution.gif")
print("GIF saved as 'function_evolution.gif'")
# Out:
# GIF saved as 'function_evolution.gif'
